# %% [markdown]
# # A/B Testing - Lab
#
# ## Introduction
#
# In this lab, you'll go through a the process of designing an experiment.
#
# ## Objectives
# You will be able to:
#
# * Design, structure, and run an A/B test
#
#
# ## The Scenario
#
# You've been tasked with designing an experiment to test whether a new email template will be more effective for your company's marketing team. The current template has a 5% response rate (with standard deviation .0475), which has outperformed numerous other templates in the past. The company is excited to test the new design that was developed internally, but nervous about losing sales if it is not to work out. As a result, they are looking to determine how many individuals they will need to serve the new email template to in order to detect a 1% performance increase (or decrease).
#
#
# ## Step 1: State the Null Hypothesis, $H_0$

# %% [markdown]
# State your null hypothesis here (be sure to make it quantitative as before)

# %%
# h_0 = new response rate is less than 0.06

# %% [markdown]
# ## Step 2: State the Alternative Hypothesis, $H_1$

# %% [markdown]
# State your alternative hypothesis here (be sure to make it quantitative as before)

# %%
# h_1 = new response rate is equal to or greater than 0.06

# %% [markdown]
# ## Step 3: Calculate n for standard alpha and power thresholds
#
# Now define what alpha and beta you believe might be appropriate for this scenario.
# To start, arbitrarily set alpha to 0.05. From this, calculate the required sample size to detect a .01 response rate difference at a power of .8.
#
# > Note: Be sure to calculate a normalized effect size using Cohen's d from the raw response rate difference.

# %%
# import class
from statsmodels.stats.power import TTestIndPower

# Calculate the required sample size

# set values
alpha = 0.05
power = 0.8

# calculate effect size
# cohens d = |mean1 - mean2| / std
mean_1 = 0.05
mean_2 = 0.06
std = 0.0475
effect_size = abs(mean_1 - mean_2) / std


# calculate sample size
power_analysis = TTestIndPower()
sample_size = power_analysis.solve_power(alpha=alpha, power=power, effect_size=effect_size,  alternative='larger')

print(sample_size)
# Out:
# 279.6667468021819

# %% [markdown]
# ## Step 4: Plot Power Curves for Alternative Experiment Formulations
#
# While you now know how many observations you need in order to run a t-test for the given formulation above, its worth exploring what sample sizes would be required for alternative test formulations. For example, how much does the required sample size increase if you put the more stringent criteria of $\alpha=.01$? Or what is the sample size required to detect a .03 response rate difference at the same $\alpha$ and power thresholds? To investigate this, plot power vs sample size curves for alpha values of .01, .05 and .1 along with varying response rate differences of .005, .01, .02 and .03.

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns


#Your code; plot power curves for the various alpha and effect size combinations

# set values
alpha_values = [0.01, 0.05, 0.1]
response_rate_differences = [0.005, 0.01, 0.02, 0.03]
std = 0.0475
effect_sizes = [difference/std for difference in response_rate_differences]


# plots
fig, axes = plt.subplots(ncols=1, nrows=3, figsize=(8,15))
for n, alpha in enumerate(alpha_values):
    ax = axes[n]
    power_analysis.plot_power(dep_var="nobs",
                             nobs=np.array(range(5,500)),
                             effect_size=effect_sizes,
                             alpha=alpha,
                             ax=ax)
    ax.set_title("Power test for alpha {}".format(alpha))
    ax.set_xticks(list(range(0,500,50)))
    ax.set_yticks(np.linspace(0,1,11))

# %% [markdown]
# ## Step 5: Propose a Final Experimental Design
#
# Finally, now that you've explored some of the various sample sizes required for statistical tests of varying power, effect size and type I errors, propose an experimental design to pitch to your boss and some of the accompanying advantages or disadvantages with it.

# %% [markdown]
# ### Your answer here

# %%
"""
The experiment would require a sample size of atleast 150 
(ideally above 280) to confidently
find an increase of response rate from %5 to %6.
Once the sample is obtained we can t-test to find the p-value and see
if it is lower than a standard alpha value such as 0.05
"""
# Out:
# '\nThe experiment would require a sample size of atleast 150 \n(ideally above 280) to confidently\nfind an increase of response rate from %5 to %6.\nOnce the sample is obtained we can t-test to find the p-value and see\nif it is lower than a standard alpha value such as 0.05\n'

# %% [markdown]
# ## Summary
#
# In this lab, you practiced designing an initial experiment and then refined the parameters of the experiment based on an initial sample to determine feasibility.
